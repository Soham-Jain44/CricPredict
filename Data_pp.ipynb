# %%
import numpy as np
import pandas as pd

# %%
cric = pd.read_csv('latest5.csv')

# %%
cric.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Match ID  \
# 0                  0            29            29          29   1339605
# 1                  1            30            30          30   1339605
# 2                  2            31            31          31   1339605
# 3                  3            32            32          32   1339605
# 4                  4            33            33          33   1339605
# ...              ...           ...           ...         ...       ...
# 118359        118359        157161        424655      424655    426724
# 118360        118360        157162        424656      424656    426724
# 118361        118361        157163        424657      424657    426724
# 118362        118362        157164        424658      424658    426724
# 118363        118363        157165        424659      424659    426724
#
#                                       Venue    Bat First    Bat Second  \
# ...

# %%
cric.Venue.value_counts()
# Out:
# Venue
# Dubai International Cricket Stadium    7300
# Shere Bangla National Stadium          7260
# R Premadasa Stadium                    5618
# New Wanderers Stadium                  4020
# Kensington Oval                        3958
#                                        ...
# St George's Park                        464
# Sir Vivian Richards Stadium             386
# Buffalo Park                            364
# Rawalpindi Cricket Stadium              189
# Gymkhana Club Ground                    189
# Name: count, Length: 75, dtype: int64

# %%
cric = cric.loc[cric.Innings == 2]

# %%
cric.head()
# Out:
#     Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Match ID  \
# 95            95           153           153         153   1339605
# 96            96           154           154         154   1339605
# 97            97           155           155         155   1339605
# 98            98           156           156         156   1339605
# 99            99           157           157         157   1339605
#
#               Venue    Bat First    Bat Second  Innings  Over  Ball  \
# 95  SuperSport Park  West Indies  South Africa        2     5     4
# 96  SuperSport Park  West Indies  South Africa        2     5     5
# 97  SuperSport Park  West Indies  South Africa        2     5     6
# 98  SuperSport Park  West Indies  South Africa        2     5     6
# 99  SuperSport Park  West Indies  South Africa        2     6     1
#
#     Innings Runs  Target Score  Chased Successfully  Wickets left        CRR  \
# ...

# %%
cric
# Out:
#         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Match ID  \
# 95                95           153           153         153   1339605
# 96                96           154           154         154   1339605
# 97                97           155           155         155   1339605
# 98                98           156           156         156   1339605
# 99                99           157           157         157   1339605
# ...              ...           ...           ...         ...       ...
# 118359        118359        157161        424655      424655    426724
# 118360        118360        157162        424656      424656    426724
# 118361        118361        157163        424657      424657    426724
# 118362        118362        157164        424658      424658    426724
# 118363        118363        157165        424659      424659    426724
#
#                                       Venue    Bat First    Bat Second  \
# ...

# %%
cric.drop("Unnamed: 0.3", axis =1)
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Match ID  \
# 95               153           153         153   1339605
# 96               154           154         154   1339605
# 97               155           155         155   1339605
# 98               156           156         156   1339605
# 99               157           157         157   1339605
# ...              ...           ...         ...       ...
# 118359        157161        424655      424655    426724
# 118360        157162        424656      424656    426724
# 118361        157163        424657      424657    426724
# 118362        157164        424658      424658    426724
# 118363        157165        424659      424659    426724
#
#                                       Venue    Bat First    Bat Second  \
# 95                          SuperSport Park  West Indies  South Africa
# 96                          SuperSport Park  West Indies  South Africa
# ...

# %%
cric.drop("Unnamed: 0", axis =1)
# Out:
#         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Match ID  \
# 95                95           153           153   1339605
# 96                96           154           154   1339605
# 97                97           155           155   1339605
# 98                98           156           156   1339605
# 99                99           157           157   1339605
# ...              ...           ...           ...       ...
# 118359        118359        157161        424655    426724
# 118360        118360        157162        424656    426724
# 118361        118361        157163        424657    426724
# 118362        118362        157164        424658    426724
# 118363        118363        157165        424659    426724
#
#                                       Venue    Bat First    Bat Second  \
# 95                          SuperSport Park  West Indies  South Africa
# 96                          SuperSport Park  West Indies  South Africa
# ...

# %%
cric = cric.drop(["Unnamed: 0.3","Unnamed: 0.2","Unnamed: 0.1","Unnamed: 0"], axis =1)

# %%
cric
# Out:
#         Match ID                                Venue    Bat First  \
# 95       1339605                      SuperSport Park  West Indies
# 96       1339605                      SuperSport Park  West Indies
# 97       1339605                      SuperSport Park  West Indies
# 98       1339605                      SuperSport Park  West Indies
# 99       1339605                      SuperSport Park  West Indies
# ...          ...                                  ...          ...
# 118359    426724  Dubai International Cricket Stadium     Pakistan
# 118360    426724  Dubai International Cricket Stadium     Pakistan
# 118361    426724  Dubai International Cricket Stadium     Pakistan
# 118362    426724  Dubai International Cricket Stadium     Pakistan
# 118363    426724  Dubai International Cricket Stadium     Pakistan
#
#           Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# 95      South Africa        2     5     4            85           259
# ...

# %%
cric = cric.reset_index()

# %%
cric
# Out:
#         index  Match ID                                Venue    Bat First  \
# 0          95   1339605                      SuperSport Park  West Indies
# 1          96   1339605                      SuperSport Park  West Indies
# 2          97   1339605                      SuperSport Park  West Indies
# 3          98   1339605                      SuperSport Park  West Indies
# 4          99   1339605                      SuperSport Park  West Indies
# ...       ...       ...                                  ...          ...
# 55824  118359    426724  Dubai International Cricket Stadium     Pakistan
# 55825  118360    426724  Dubai International Cricket Stadium     Pakistan
# 55826  118361    426724  Dubai International Cricket Stadium     Pakistan
# 55827  118362    426724  Dubai International Cricket Stadium     Pakistan
# 55828  118363    426724  Dubai International Cricket Stadium     Pakistan
#
#          Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# ...

# %%
cric = cric.drop('index', axis =1)

# %%
cric
# Out:
#        Match ID                                Venue    Bat First  \
# 0       1339605                      SuperSport Park  West Indies
# 1       1339605                      SuperSport Park  West Indies
# 2       1339605                      SuperSport Park  West Indies
# 3       1339605                      SuperSport Park  West Indies
# 4       1339605                      SuperSport Park  West Indies
# ...         ...                                  ...          ...
# 55824    426724  Dubai International Cricket Stadium     Pakistan
# 55825    426724  Dubai International Cricket Stadium     Pakistan
# 55826    426724  Dubai International Cricket Stadium     Pakistan
# 55827    426724  Dubai International Cricket Stadium     Pakistan
# 55828    426724  Dubai International Cricket Stadium     Pakistan
#
#          Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# 0      South Africa        2     5     4            85           259
# ...

# %%
cric.Venue.value_counts()
# Out:
# Venue
# Shere Bangla National Stadium          3452
# Dubai International Cricket Stadium    3377
# R Premadasa Stadium                    2593
# Kensington Oval                        1917
# New Wanderers Stadium                  1868
#                                        ...
# St George's Park                        220
# Sir Vivian Richards Stadium             197
# Buffalo Park                            181
# Gymkhana Club Ground                     95
# Rawalpindi Cricket Stadium               93
# Name: count, Length: 75, dtype: int64

# %%
cric['Balls_left'] = 126 - ((cric['Over'] * 6) +cric['Ball'])

# %%
cric
# Out:
#        Match ID                                Venue    Bat First  \
# 0       1339605                      SuperSport Park  West Indies
# 1       1339605                      SuperSport Park  West Indies
# 2       1339605                      SuperSport Park  West Indies
# 3       1339605                      SuperSport Park  West Indies
# 4       1339605                      SuperSport Park  West Indies
# ...         ...                                  ...          ...
# 55824    426724  Dubai International Cricket Stadium     Pakistan
# 55825    426724  Dubai International Cricket Stadium     Pakistan
# 55826    426724  Dubai International Cricket Stadium     Pakistan
# 55827    426724  Dubai International Cricket Stadium     Pakistan
# 55828    426724  Dubai International Cricket Stadium     Pakistan
#
#          Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# 0      South Africa        2     5     4            85           259
# ...

# %%
cric['Bowls_done'] = 120 - cric['Balls_left']
cric['Runs_remaining'] = cric['Target Score'] - cric['Innings Runs']
cric
# Out:
#        Match ID                                Venue    Bat First  \
# 0       1339605                      SuperSport Park  West Indies
# 1       1339605                      SuperSport Park  West Indies
# 2       1339605                      SuperSport Park  West Indies
# 3       1339605                      SuperSport Park  West Indies
# 4       1339605                      SuperSport Park  West Indies
# ...         ...                                  ...          ...
# 55824    426724  Dubai International Cricket Stadium     Pakistan
# 55825    426724  Dubai International Cricket Stadium     Pakistan
# 55826    426724  Dubai International Cricket Stadium     Pakistan
# 55827    426724  Dubai International Cricket Stadium     Pakistan
# 55828    426724  Dubai International Cricket Stadium     Pakistan
#
#          Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# 0      South Africa        2     5     4            85           259
# ...

# %%
cric = cric.loc[cric.Balls_left != 0]
cric
# Out:
#        Match ID                                Venue    Bat First  \
# 0       1339605                      SuperSport Park  West Indies
# 1       1339605                      SuperSport Park  West Indies
# 2       1339605                      SuperSport Park  West Indies
# 3       1339605                      SuperSport Park  West Indies
# 4       1339605                      SuperSport Park  West Indies
# ...         ...                                  ...          ...
# 55823    426724  Dubai International Cricket Stadium     Pakistan
# 55824    426724  Dubai International Cricket Stadium     Pakistan
# 55825    426724  Dubai International Cricket Stadium     Pakistan
# 55826    426724  Dubai International Cricket Stadium     Pakistan
# 55827    426724  Dubai International Cricket Stadium     Pakistan
#
#          Bat Second  Innings  Over  Ball  Innings Runs  Target Score  \
# 0      South Africa        2     5     4            85           259
# ...

# %%
cric = cric.drop(['Match ID', 'Innings', 'Over', 'Ball'], axis = 1)
cric
# Out:
#                                      Venue    Bat First    Bat Second  \
# 0                          SuperSport Park  West Indies  South Africa
# 1                          SuperSport Park  West Indies  South Africa
# 2                          SuperSport Park  West Indies  South Africa
# 3                          SuperSport Park  West Indies  South Africa
# 4                          SuperSport Park  West Indies  South Africa
# ...                                    ...          ...           ...
# 55823  Dubai International Cricket Stadium     Pakistan   New Zealand
# 55824  Dubai International Cricket Stadium     Pakistan   New Zealand
# 55825  Dubai International Cricket Stadium     Pakistan   New Zealand
# 55826  Dubai International Cricket Stadium     Pakistan   New Zealand
# 55827  Dubai International Cricket Stadium     Pakistan   New Zealand
#
#        Innings Runs  Target Score  Chased Successfully  Wickets left  \
# ...

# %%
random_cric = cric.sample(n=len(cric))
random_cric = random_cric.reset_index(drop = True)

# %%
random_cric
# Out:
#                                               Venue     Bat First  \
# 0                             New Wanderers Stadium     Australia
# 1                               R.Premadasa Stadium    Bangladesh
# 2           Pallekele International Cricket Stadium     Sri Lanka
# 3                          Melbourne Cricket Ground         India
# 4                             M Chinnaswamy Stadium         India
# ...                                             ...           ...
# 55607                         The Wanderers Stadium         India
# 55608  Punjab Cricket Association IS Bindra Stadium   New Zealand
# 55609                         New Wanderers Stadium  South Africa
# 55610                         New Wanderers Stadium   West Indies
# 55611                 Shere Bangla National Stadium    Bangladesh
#
#          Bat Second  Innings Runs  Target Score  Chased Successfully  \
# 0      South Africa            70           167                    1
# ...

# %%
final_cric = pd.get_dummies(random_cric, columns = ['Venue', 'Bat First', 'Bat Second'])

final_cric = final_cric*1

# %%
final_cric
# Out:
#        Innings Runs  Target Score  Chased Successfully  Wickets left  \
# 0                70           167                    1            10
# 1                83           140                    1            10
# 2               184           216                    0            10
# 3                66            75                    1            10
# 4                94           147                    0            10
# ...             ...           ...                  ...           ...
# 55607            85           204                    0            10
# 55608           122           181                    0            10
# 55609           163           202                    0            10
# 55610            86           206                    1            10
# 55611            24           109                    1            10
#
#             CRR  Last Five        RRR  Balls_left  Bowls_done  Runs_remaining  \
# ...

# %%
X = final_cric.drop('Chased Successfully', axis = 1)
Y = final_cric['Chased Successfully']
X
# Out:
#        Innings Runs  Target Score  Wickets left       CRR  Last Five  \
# 0                70           167            10  6.000000       24.0
# 1                83           140            10  7.114286       34.0
# 2               184           216            10  8.975610       32.0
# 3                66            75            10  6.491803       38.0
# 4                94           147            10  7.421053       38.0
# ...             ...           ...           ...       ...        ...
# 55607            85           204            10  7.183099       36.0
# 55608           122           181            10  7.705263       32.0
# 55609           163           202            10  9.140187       51.0
# 55610            86           206            10  9.555556       37.0
# 55611            24           109            10  3.789474       16.0
#
#              RRR  Balls_left  Bowls_done  Runs_remaining  Venue_Adelaide Oval  \
# ...

# %%
Y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 55607    0
# 55608    0
# 55609    0
# 55610    1
# 55611    1
# Name: Chased Successfully, Length: 55612, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
y_test
# Out:
# 31150    0
# 39480    1
# 9197     1
# 4207     1
# 30752    0
#         ..
# 39908    1
# 29532    1
# 14543    1
# 17037    1
# 52723    0
# Name: Chased Successfully, Length: 11123, dtype: int64

# %%
final_cric.to_csv("final.csv")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Use 'softmax' for multi-class classification
])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'
